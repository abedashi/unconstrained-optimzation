# %% [markdown]
# #### Dependencies

# %%
import numpy as np
from algorithms.utils.rosenbrock import rosenbrock
from algorithms.utils.plot import plot_combined_results, plot
from algorithms.utils.print_result import print_result
from tests.test_optimization_method import run_optimization_method

np.random.seed(336648)

# %% [markdown]
# #### Initial points = [1.2, 1.2]

# %%
initial_point = np.array([1.2, 1.2])

print("COST OF ROSENBROCK BEFORE OPTIMIZATION:", rosenbrock(initial_point))

print("\nRunning Modified Newton Test...")
result_n, trajectory_n = run_optimization_method("Modified Newton", "Rosenbrock", initial_point, tol=1e-5, max_iter=1000)
print_result(result_n)

print("\nRunning Steepest Descent Test...")
result_s, trajectory_s = run_optimization_method("Steepest Descent", "Rosenbrock", initial_point, tol=1e-5, max_iter=1000)
print_result(result_s)

plot_combined_results(rosenbrock, trajectory_n, trajectory_s, 'Rosenbrock', 'initail_1', [1, 1], [1, 1])
# Out:
# COST OF ROSENBROCK BEFORE OPTIMIZATION: 5.8
#
# Running Modified Newton Test...
# Start Point: [1.2, 1.2]
# Final Point: [1.000000194435934, 1.0000003862596314]
# Cost of Rosenbrock: 3.8487730190653475e-14
# Iterations: 7
# Execution Time (s): 0.0009000301361083984
# Success: True
# Gradiant norm: 1.5260044026127449e-06
# Experimental Rate of Convergence: 0.4813338236810633
#
# Running Steepest Descent Test...
# Start Point: [1.2, 1.2]
# Final Point: [1.0127633024055922, 1.0253682454211468]
# Cost of Rosenbrock: 0.0001732227691922814
# Iterations: 1000
# Execution Time (s): 0.034800052642822266
# Success: False
# Gradiant norm: 0.1684098956461894
# Experimental Rate of Convergence: 1.003217409867159
# Convergence plot saved to assets/Rosenbrock/initail_1_convergence_plot.png
# Path plot saved to assets/Rosenbrock/initail_1_path_plot.png

# %% [markdown]
# #### Initial points = [-1.2, 1]

# %%
initial_point = np.array([-1.2, 1])

print("COST OF ROSENBROCK BEFORE OPTIMIZATION:", rosenbrock(initial_point))

print("Running Modified Test...")
result_n, trajectory_n = run_optimization_method("Modified Newton", "Rosenbrock", initial_point, tol=1e-4, max_iter=1000)
print_result(result_n)

print("\nRunning Steepest Descent Test...")
result_s, trajectory_s = run_optimization_method("Steepest Descent", "Rosenbrock", initial_point, tol=1e-4, max_iter=1000)
print_result(result_s)

plot_combined_results(rosenbrock, trajectory_n, trajectory_s, 'Rosenbrock', 'initail_2', [1, 1], [1, 1])
# Out:
# COST OF ROSENBROCK BEFORE OPTIMIZATION: 24.199999999999996
# Running Modified Test...
# Start Point: [-1.2, 1.0]
# Final Point: [0.9999999991097481, 0.9999999982106182]
# Cost of Rosenbrock: 8.004303011522404e-19
# Iterations: 21
# Execution Time (s): 0.0059587955474853516
# Success: True
# Gradiant norm: 2.5076165282007706e-09
# Experimental Rate of Convergence: 0.6899078043247009
#
# Running Steepest Descent Test...
# Start Point: [-1.2, 1.0]
# Final Point: [0.9727759362126378, 0.9460232983938567]
# Cost of Rosenbrock: 0.000748424735481543
# Iterations: 1000
# Execution Time (s): 0.04437518119812012
# Success: False
# Gradiant norm: 0.07389657773655635
# Experimental Rate of Convergence: 0.9914687192308195
# Convergence plot saved to assets/Rosenbrock/initail_2_convergence_plot.png
# Path plot saved to assets/Rosenbrock/initail_2_path_plot.png
